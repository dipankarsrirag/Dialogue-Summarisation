# %%
import pandas as pd

# %%
train = pd.read_json('../data/raw/dialogsum/dialogsum.train.jsonl', lines = True)
train.head()
# Out:
#      fname                                           dialogue  \
# 0  train_0  #Person1#: Hi, Mr. Smith. I'm Doctor Hawkins. ...
# 1  train_1  #Person1#: Hello Mrs. Parker, how have you bee...
# 2  train_2  #Person1#: Excuse me, did you see a set of key...
# 3  train_3  #Person1#: Why didn't you tell me you had a gi...
# 4  train_4  #Person1#: Watsup, ladies! Y'll looking'fine t...
#
#                                              summary              topic
# 0  Mr. Smith's getting a check-up, and Doctor Haw...     get a check-up
# 1  Mrs Parker takes Ricky for his vaccines. Dr. P...           vaccines
# 2  #Person1#'s looking for a set of keys and asks...          find keys
# 3  #Person1#'s angry because #Person2# didn't tel...  have a girlfriend
# 4  Malik invites Nikki to dance. Nikki agrees if ...              dance

# %%
train.drop(columns=['fname'], inplace=True)

# %%
train
# Out:
#                                                 dialogue  \
# 0      #Person1#: Hi, Mr. Smith. I'm Doctor Hawkins. ...
# 1      #Person1#: Hello Mrs. Parker, how have you bee...
# 2      #Person1#: Excuse me, did you see a set of key...
# 3      #Person1#: Why didn't you tell me you had a gi...
# 4      #Person1#: Watsup, ladies! Y'll looking'fine t...
# ...                                                  ...
# 12455  #Person1#: Excuse me. You are Mr. Green from M...
# 12456  #Person1#: Mister Ewing said we should show up...
# 12457  #Person1#: How can I help you today?\n#Person2...
# 12458  #Person1#: You look a bit unhappy today. What'...
# 12459  #Person1#: Mom, I'm flying to visit uncle Lee'...
#
#                                                  summary              topic
# 0      Mr. Smith's getting a check-up, and Doctor Haw...     get a check-up
# 1      Mrs Parker takes Ricky for his vaccines. Dr. P...           vaccines
# ...

# %%
dev = pd.read_json('../data/raw/dialogsum/dialogsum.dev.jsonl', lines= True)
dev.head()
# Out:
#    fname                                           dialogue  \
# 0  dev_0  #Person1#: Hello, how are you doing today?\n#P...
# 1  dev_1  #Person1#: Hey Jimmy. Let's go workout later t...
# 2  dev_2  #Person1#: I need to stop eating such unhealth...
# 3  dev_3  #Person1#: Do you believe in UFOs?\n#Person2#:...
# 4  dev_4  #Person1#: Did you go to school today?\n#Perso...
#
#                                              summary            topic
# 0  #Person2# has trouble breathing. The doctor as...     see a doctor
# 1  #Person1# invites Jimmy to go workout and pers...      do exercise
# 2  #Person1# plans to stop eating unhealthy foods...    healthy foods
# 3  #Person2# believes in UFOs and can see them in...  UFOs and aliens
# 4  #Person1# didn't go to school today. #Person2#...     go to school

# %%
dev.drop(columns=['fname'], inplace= True)

# %%
dev
# Out:
#                                               dialogue  \
# 0    #Person1#: Hello, how are you doing today?\n#P...
# 1    #Person1#: Hey Jimmy. Let's go workout later t...
# 2    #Person1#: I need to stop eating such unhealth...
# 3    #Person1#: Do you believe in UFOs?\n#Person2#:...
# 4    #Person1#: Did you go to school today?\n#Perso...
# ..                                                 ...
# 495  #Person1#: Now that it's the new year, I've de...
# 496  #Person1#: You married Joe, didn't you? \n#Per...
# 497  #Person1#: How can I help you mam?\n#Person2#:...
# 498  #Person1#: Hello, Amazon's customer service. H...
# 499  #Person1#: I can't believe it's almost summer....
#
#                                                summary            topic
# 0    #Person2# has trouble breathing. The doctor as...     see a doctor
# 1    #Person1# invites Jimmy to go workout and pers...      do exercise
# 2    #Person1# plans to stop eating unhealthy foods...    healthy foods
# ...

# %%
test = pd.read_json('../data/raw/dialogsum/dialogsum.test.jsonl', lines= True)
test.head()
# Out:
#     fname                                           dialogue  \
# 0  test_0  #Person1#: Ms. Dawson, I need you to take a di...
# 1  test_1  #Person1#: You're finally here! What took so l...
# 2  test_2  #Person1#: Kate, you never believe what's happ...
# 3  test_3  #Person1#: Happy Birthday, this is for you, Br...
# 4  test_4  #Person1#: This Olympic park is so big!\n#Pers...
#
#                                             summary1                 topic1  \
# 0  Ms. Dawson helps #Person1# to write a memo to ...   communication method
# 1  #Person2# arrives late because of traffic jam....  public transportation
# 2  #Person1# tells Kate that Masha and Hero get d...                divorce
# 3  #Person1# and Brian are at the birthday party ...         birthday party
# 4  #Person1# is surprised at the Olympic Stadium'...        Olympic Stadium
#
#                                             summary2          topic2  \
# ...

# %%
test.drop(columns = ['fname'], inplace = True)

# %%
test
# Out:
#                                               dialogue  \
# 0    #Person1#: Ms. Dawson, I need you to take a di...
# 1    #Person1#: You're finally here! What took so l...
# 2    #Person1#: Kate, you never believe what's happ...
# 3    #Person1#: Happy Birthday, this is for you, Br...
# 4    #Person1#: This Olympic park is so big!\n#Pers...
# ..                                                 ...
# 495  #Person1#: Hey, Charlie, do you want to come t...
# 496  #Person1#: How did you get interested in count...
# 497  #Person1#: Excuse me, Alice, I've never used t...
# 498  #Person1#: Matthew? Hi!\n#Person2#: Steve! Hav...
# 499  #Person1#: Hey, Betsy, did you hear the great ...
#
#                                               summary1  \
# 0    Ms. Dawson helps #Person1# to write a memo to ...
# 1    #Person2# arrives late because of traffic jam....
# 2    #Person1# tells Kate that Masha and Hero get d...
# 3    #Person1# and Brian are at the birthday party ...
# ...

# %%
print(test['dialogue'].iloc[498])
# Out:
# #Person1#: Matthew? Hi!
# #Person2#: Steve! Haven't seen you in ages! How long's it been?
# #Person1#: it's got to be almost a year now.
# #Person2#: how have you been?
# #Person1#: I'm pretty good. I've been looking for a place to live recently. My lease runs out next month and I don't want to renew it.
# #Person2#: yeah, I remember the neighborhood. Have you found a place yet?
# #Person1#: not yet. I am still looking through the classifieds. Wish me luck.
# #Person2#: well, maybe I can help. Remember my neighbor?
# #Person1#: Mrs. Thou?
# #Person2#: yes, her daughter's having a baby, so she's moving in with her to help out. I think if you are interested, you can come over and have a look.
# #Person1#: great. It's a lovely neighborhood. And it would be nice to be neighbors again. It would be just like the old days!
# #Person2#: I'll ask Mrs. Thou when she's available to show the apartment and let you know. Has your number changed?
